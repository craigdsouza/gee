# %%
#! pip install geemap
# Out:
# Collecting geemap
#   Downloading geemap-0.13.4-py2.py3-none-any.whl (2.0 MB)
# Collecting ipytree
#   Downloading ipytree-0.2.1-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied: matplotlib in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from geemap) (3.4.1)
# Collecting pycrs
#   Downloading PyCRS-1.0.2.tar.gz (36 kB)
# Requirement already satisfied: jupyterlab>=3 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from geemap) (3.0.12)
# Collecting xyzservices
#   Downloading xyzservices-2022.4.0-py3-none-any.whl (36 kB)
# Collecting gdown
#   Downloading gdown-4.4.0.tar.gz (14 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: pandas in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from geemap) (1.2.3)
# Collecting folium>=0.11.0
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting ipyfilechooser>=0.6.0
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Collecting python-box
#   Downloading python_box-6.0.2-cp37-cp37m-win_amd64.whl (927 kB)
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
# Collecting bqplot
#   Downloading bqplot-0.12.33-py2.py3-none-any.whl (1.2 MB)
# Requirement already satisfied: pillow in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from geemap) (8.1.2)
# Collecting geeadd>=0.5.1
#   Downloading geeadd-0.5.5-py3-none-any.whl (30 kB)
# Collecting ipyevents
#   Downloading ipyevents-2.0.1-py2.py3-none-any.whl (130 kB)
# Requirement already satisfied: geojson in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from geemap) (2.5.0)
# Collecting pyshp>=2.1.3
#   Downloading pyshp-2.3.0-py2.py3-none-any.whl (46 kB)
# Collecting earthengine-api>=0.1.304
#   Downloading earthengine-api-0.1.307.tar.gz (238 kB)
# Collecting sankee
#   Downloading sankee-0.0.7.tar.gz (29 kB)
# Collecting whiteboxgui>=0.6.0
#   Downloading whiteboxgui-0.7.0-py2.py3-none-any.whl (99 kB)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from geemap) (1.20.2)
# Collecting ipyleaflet>=0.14.0
#   Downloading ipyleaflet-0.16.0-py2.py3-none-any.whl (3.3 MB)
# Collecting ee-extra>=0.0.10
#   Downloading ee_extra-0.0.13.tar.gz (187 kB)
# Collecting mapclassify>=2.4.0
#   Downloading mapclassify-2.4.3-py3-none-any.whl (38 kB)
# Requirement already satisfied: future in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.304->geemap) (0.18.2)
# Requirement already satisfied: google-cloud-storage in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.304->geemap) (2.1.0)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.304->geemap) (1.12.8)
# Requirement already satisfied: google-auth>=1.4.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.304->geemap) (1.28.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.304->geemap) (0.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.304->geemap) (0.19.1)
# Requirement already satisfied: httplib2shim in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.304->geemap) (0.0.3)
# Requirement already satisfied: six in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.304->geemap) (1.15.0)
# Requirement already satisfied: requests in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from folium>=0.11.0->geemap) (2.25.1)
# Requirement already satisfied: jinja2>=2.9 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from folium>=0.11.0->geemap) (2.11.3)
# Collecting branca>=0.3.0
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: logzero>=1.5.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from geeadd>=0.5.1->geemap) (1.7.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from geeadd>=0.5.1->geemap) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from beautifulsoup4>=4.9.0->geeadd>=0.5.1->geemap) (2.2.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (3.0.1)
# Collecting google-api-core<2dev,>=1.21.0
#   Downloading google_api_core-1.31.5-py2.py3-none-any.whl (93 kB)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (1.53.0)
# Requirement already satisfied: protobuf>=3.12.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (3.15.8)
# Requirement already satisfied: pytz in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (2021.1)
# Requirement already satisfied: setuptools>=40.3.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (52.0.0.post20210125)
# Requirement already satisfied: packaging>=14.3 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (20.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.2.7)
# Requirement already satisfied: pyparsing<3,>=2.4.2 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=0.1.304->geemap) (2.4.7)
# Collecting ipywidgets
#   Downloading ipywidgets-7.7.0-py2.py3-none-any.whl (123 kB)
# Collecting traittypes<3,>=0.2.1
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: nbformat>=4.2.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.1.3)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.1.0-py3-none-any.whl (245 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.5.3)
# Requirement already satisfied: traitlets>=4.3.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.0.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: ipython>=4.0.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.22.0)
# Requirement already satisfied: jupyter-client in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.1)
# Requirement already satisfied: pygments in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.8.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.18)
# Requirement already satisfied: colorama in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4.4)
# Requirement already satisfied: decorator in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.0.5)
# Requirement already satisfied: jedi>=0.16 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.0)
# Requirement already satisfied: pickleshare in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: backcall in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (1.1.1)
# Requirement already satisfied: nbclassic~=0.2 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyterlab>=3->geemap) (0.2.6)
# Requirement already satisfied: jupyter-server~=1.4 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyterlab>=3->geemap) (1.5.1)
# Requirement already satisfied: jupyter-packaging~=0.7.3 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyterlab>=3->geemap) (0.7.12)
# Requirement already satisfied: jupyter-core in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyterlab>=3->geemap) (4.7.1)
# Requirement already satisfied: jupyterlab-server~=2.3 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyterlab>=3->geemap) (2.4.0)
# Requirement already satisfied: pyzmq>=17 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (22.0.3)
# Requirement already satisfied: argon2-cffi in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (20.1.0)
# Requirement already satisfied: nbconvert in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (6.0.7)
# Requirement already satisfied: Send2Trash in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (0.9.4)
# Requirement already satisfied: prometheus_client in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (0.10.0)
# Requirement already satisfied: anyio>=2.0.2 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (2.2.0)
# Requirement already satisfied: pywin32>=1.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (300)
# Requirement already satisfied: sniffio>=1.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.2.0)
# Requirement already satisfied: idna>=2.8 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab>=3->geemap) (2.10)
# Requirement already satisfied: typing-extensions in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab>=3->geemap) (3.7.4.3)
# Requirement already satisfied: python-dateutil>=2.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.8.1)
# Requirement already satisfied: jsonschema>=3.0.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (3.2.0)
# Requirement already satisfied: babel in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (2.9.0)
# Requirement already satisfied: json5 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.9.5)
# Requirement already satisfied: pyrsistent>=0.14.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (20.3.0)
# Requirement already satisfied: importlib-metadata in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (3.10.0)
# Collecting networkx
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from mapclassify>=2.4.0->geemap) (1.6.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp37-cp37m-win_amd64.whl (7.1 MB)
# Requirement already satisfied: notebook<7 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from nbclassic~=0.2->jupyterlab>=3->geemap) (6.3.0)
# Requirement already satisfied: wcwidth in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from requests->folium>=0.11.0->geemap) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from requests->folium>=0.11.0->geemap) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from requests->folium>=0.11.0->geemap) (4.0.0)
# Requirement already satisfied: pywinpty>=0.5 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from terminado>=0.8.3->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.7)
# Collecting whitebox
#   Downloading whitebox-2.1.2-py2.py3-none-any.whl (75 kB)
# Requirement already satisfied: cffi>=1.0.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.14.5)
# Requirement already satisfied: pycparser in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server~=1.4->jupyterlab>=3->geemap) (2.20)
# Requirement already satisfied: tqdm in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from gdown->geemap) (4.60.0)
# Collecting filelock
#   Downloading filelock-3.6.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: click in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from geocoder->geemap) (7.1.2)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.2.2)
# Requirement already satisfied: google-resumable-media>=1.3.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.1.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from google-resumable-media>=1.3.0->google-cloud-storage->earthengine-api>=0.1.304->geemap) (1.1.2)
# Requirement already satisfied: zipp>=0.5 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from importlib-metadata->jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (3.4.1)
# Requirement already satisfied: cycler>=0.10 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from matplotlib->geemap) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.3)
# Requirement already satisfied: testpath in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.4.2)
# Requirement already satisfied: defusedxml in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.7.1)
# Requirement already satisfied: bleach in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (3.3.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.3)
# Requirement already satisfied: async-generator in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.10)
# Requirement already satisfied: nest-asyncio in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.5.1)
# Requirement already satisfied: webencodings in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in g:\users\craig\miniconda3\envs\geo_env\lib\site-packages (from requests->folium>=0.11.0->geemap) (1.7.1)
# Collecting plotly>=5.2.2
#   Downloading plotly-5.7.0-py2.py3-none-any.whl (28.8 MB)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Building wheels for collected packages: earthengine-api, ee-extra, gdown, pycrs, sankee
#   Building wheel for earthengine-api (setup.py): started
#   Building wheel for earthengine-api (setup.py): finished with status 'done'
#   Created wheel for earthengine-api: filename=earthengine_api-0.1.307-py3-none-any.whl size=268111 sha256=01426f96ab3c285c618bc1d2b31e8b2bdb74fc8ecdb8f4f9460fa22d33109561
#   Stored in directory: c:\users\craig d\appdata\local\pip\cache\wheels\ac\f8\f3\3097750e525cb70b2f16cdbed11734988bee5be1e0e90d7edf
#   Building wheel for ee-extra (setup.py): started
#   Building wheel for ee-extra (setup.py): finished with status 'done'
#   Created wheel for ee-extra: filename=ee_extra-0.0.13-py3-none-any.whl size=198382 sha256=e321bc28e3e2caf034329901eefeeba906aafdb23385778f02e462dfef12be03
#   Stored in directory: c:\users\craig d\appdata\local\pip\cache\wheels\54\f2\bc\51930fbbffdd2ef1b5aac2e332c068e4913e56634f90efdef8
#   Building wheel for gdown (PEP 517): started
#   Building wheel for gdown (PEP 517): finished with status 'done'
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14775 sha256=9cd23754b13cd2f5a46021251d958505cc9a75beb41e01fda8cc2748ec8a9b7e
#   Stored in directory: c:\users\craig d\appdata\local\pip\cache\wheels\fb\c3\0e\c4d8ff8bfcb0461afff199471449f642179b74968c15b7a69c
#   Building wheel for pycrs (setup.py): started
#   Building wheel for pycrs (setup.py): finished with status 'done'
#   Created wheel for pycrs: filename=PyCRS-1.0.2-py3-none-any.whl size=32680 sha256=31c4311773b31b2765e2be466ce4d9073939da38bc68a7010b10f95840a22ac4
#   Stored in directory: c:\users\craig d\appdata\local\pip\cache\wheels\3e\ce\32\1ec0aba6b9770681a423e82f0274c57d09ad2c20c2864901f9
#   Building wheel for sankee (setup.py): started
#   Building wheel for sankee (setup.py): finished with status 'done'
#   Created wheel for sankee: filename=sankee-0.0.7-py3-none-any.whl size=27626 sha256=30c773ace9f6adb13c21833bc1f5167bf40205aaf498441df473c308da22a02f
#   Stored in directory: c:\users\craig d\appdata\local\pip\cache\wheels\13\28\83\5726f82a8cb0baf76169d99ee0595c420afedb9020e22bbd4b
# Successfully built earthengine-api ee-extra gdown pycrs sankee
# Installing collected packages: google-api-core, widgetsnbextension, jupyterlab-widgets, threadpoolctl, tenacity, joblib, ipywidgets, xyzservices, whitebox, traittypes, scikit-learn, ratelim, plotly, networkx, ipytree, ipyfilechooser, filelock, earthengine-api, branca, whiteboxgui, sankee, python-box, pyshp, pycrs, mapclassify, ipyleaflet, ipyevents, geocoder, geeadd, gdown, folium, ffmpeg-python, ee-extra, colour, bqplot, geemap
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.4.0
#     Uninstalling google-api-core-2.4.0:
#       Successfully uninstalled google-api-core-2.4.0
#   Attempting uninstall: plotly
#     Found existing installation: plotly 4.14.3
#     Uninstalling plotly-4.14.3:
#       Successfully uninstalled plotly-4.14.3
#   Attempting uninstall: earthengine-api
#     Found existing installation: earthengine-api 0.1.261
#     Uninstalling earthengine-api-0.1.261:
#       Successfully uninstalled earthengine-api-0.1.261
# Successfully installed bqplot-0.12.33 branca-0.5.0 colour-0.1.5 earthengine-api-0.1.307 ee-extra-0.0.13 ffmpeg-python-0.2.0 filelock-3.6.0 folium-0.12.1.post1 gdown-4.4.0 geeadd-0.5.5 geemap-0.13.4 geocoder-1.38.1 google-api-core-1.31.5 ipyevents-2.0.1 ipyfilechooser-0.6.0 ipyleaflet-0.16.0 ipytree-0.2.1 ipywidgets-7.7.0 joblib-1.1.0 jupyterlab-widgets-1.1.0 mapclassify-2.4.3 networkx-2.6.3 plotly-5.7.0 pycrs-1.0.2 pyshp-2.3.0 python-box-6.0.2 ratelim-0.1.6 sankee-0.0.7 scikit-learn-1.0.2 tenacity-8.0.1 threadpoolctl-3.1.0 traittypes-0.2.1 whitebox-2.1.2 whiteboxgui-0.7.0 widgetsnbextension-3.6.0 xyzservices-2022.4.0

# %%
# !jupyter nbextension list
# Out:
# Known nbextensions:
#   config dir: C:\Users\Craig D\.jupyter\nbconfig
#     notebook section
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: problems found:
#         - require?  X nbextensions_configurator/config_menu/main
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: problems found:
#         - require?  X nbextensions_configurator/tree_tab/main
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       execute_time/ExecuteTime enabled
#       toc2/main enabled
#       hide_input_all/main enabled
#       nbextensions_configurator/config_menu/main enabled
#       contrib_nbextensions_help_item/main enabled
#       collapsible_headings/main enabled
#       codefolding/main enabled
#     tree section
#       nbextensions_configurator/tree_tab/main enabled
#   config dir: G:\Users\Craig\miniconda3\envs\geo_env\etc\jupyter\nbconfig
#     notebook section
#       bqplot/extension enabled
#       ipyevents/extension enabled
#       ipytree/extension enabled
#       jupyter-leaflet/extension enabled
#       jupyterlab-plotly/extension enabled
#       plotlywidget/extension enabled
#       jupyter-js-widgets/extension enabled

# %%
import geemap
from ipywidgets import Layout

# %%
geemap.show_youtube('h0pz3S6Tvx0')
# Out:
# Output(layout=Layout(width='815px'))

# %%
Map = geemap.Map(
    center=(20,80),
    zoom=4,
    layout=Layout(width='80%', height='250px')
)
Map
# Out:
# Map(center=[20, 80], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Tog…

# %%
Map.add_basemap('HYBRID')

# %%
basemaps = geemap.basemaps
for basemap in basemaps:
    print(basemap)
# Out:
# OpenStreetMap
# ROADMAP
# SATELLITE
# TERRAIN
# HYBRID
# FWS NWI Wetlands
# FWS NWI Wetlands Raster
# NLCD 2019 CONUS Land Cover
# NLCD 2016 CONUS Land Cover
# NLCD 2013 CONUS Land Cover
# NLCD 2011 CONUS Land Cover
# NLCD 2008 CONUS Land Cover
# NLCD 2006 CONUS Land Cover
# NLCD 2004 CONUS Land Cover
# NLCD 2001 CONUS Land Cover
# USGS NAIP Imagery
# USGS Hydrography
# USGS 3DEP Elevation
# BasemapAT.basemap
# BasemapAT.grau
# BasemapAT.highdpi
# BasemapAT.orthofoto
# BasemapAT.overlay
# BasemapAT.surface
# BasemapAT.terrain
# CartoDB.DarkMatter
# CartoDB.DarkMatterNoLabels
# CartoDB.DarkMatterOnlyLabels
# CartoDB.Positron
# CartoDB.PositronNoLabels
# CartoDB.PositronOnlyLabels
# CartoDB.Voyager
# CartoDB.VoyagerLabelsUnder
# CartoDB.VoyagerNoLabels
# CartoDB.VoyagerOnlyLabels
# CyclOSM
# Esri.AntarcticBasemap
# Esri.ArcticOceanBase
# Esri.ArcticOceanReference
# Esri.DeLorme
# Esri.NatGeoWorldMap
# Esri.OceanBasemap
# Esri.WorldGrayCanvas
# Esri.WorldImagery
# Esri.WorldPhysical
# Esri.WorldShadedRelief
# Esri.WorldStreetMap
# Esri.WorldTerrain
# Esri.WorldTopoMap
# FreeMapSK
# Gaode.Normal
# Gaode.Satellite
# GeoportailFrance.orthos
# GeoportailFrance.parcels
# GeoportailFrance.plan
# HikeBike.HikeBike
# HikeBike.HillShading
# JusticeMap.americanIndian
# JusticeMap.asian
# JusticeMap.black
# JusticeMap.hispanic
# JusticeMap.income
# JusticeMap.multi
# JusticeMap.nonWhite
# JusticeMap.plurality
# JusticeMap.white
# MtbMap
# NASAGIBS.BlueMarble
# NASAGIBS.BlueMarble3031
# NASAGIBS.BlueMarble3413
# NASAGIBS.ModisAquaBands721CR
# NASAGIBS.ModisAquaTrueColorCR
# NASAGIBS.ModisTerraAOD
# NASAGIBS.ModisTerraBands367CR
# NASAGIBS.ModisTerraBands721CR
# NASAGIBS.ModisTerraChlorophyll
# NASAGIBS.ModisTerraLSTDay
# NASAGIBS.ModisTerraSnowCover
# NASAGIBS.ModisTerraTrueColorCR
# NASAGIBS.ViirsEarthAtNight2012
# NASAGIBS.ViirsTrueColorCR
# NLS
# OPNVKarte
# OneMapSG.Default
# OneMapSG.Grey
# OneMapSG.LandLot
# OneMapSG.Night
# OneMapSG.Original
# OpenAIP
# OpenFireMap
# OpenRailwayMap
# OpenSeaMap
# OpenSnowMap.pistes
# OpenStreetMap.BZH
# OpenStreetMap.BlackAndWhite
# OpenStreetMap.CH
# OpenStreetMap.DE
# OpenStreetMap.France
# OpenStreetMap.HOT
# OpenStreetMap.Mapnik
# OpenTopoMap
# SafeCast
# Stadia.AlidadeSmooth
# Stadia.AlidadeSmoothDark
# Stadia.OSMBright
# Stadia.Outdoors
# Stamen.Terrain
# Stamen.TerrainBackground
# Stamen.TerrainLabels
# Stamen.Toner
# Stamen.TonerBackground
# Stamen.TonerHybrid
# Stamen.TonerLabels
# Stamen.TonerLines
# Stamen.TonerLite
# Stamen.TopOSMFeatures
# Stamen.TopOSMRelief
# Stamen.Watercolor
# Strava.All
# Strava.Ride
# Strava.Run
# Strava.Water
# Strava.Winter
# SwissFederalGeoportal.JourneyThroughTime
# SwissFederalGeoportal.NationalMapColor
# SwissFederalGeoportal.NationalMapGrey
# SwissFederalGeoportal.SWISSIMAGE
# USGS.USImagery
# USGS.USImageryTopo
# USGS.USTopo
# WaymarkedTrails.cycling
# WaymarkedTrails.hiking
# WaymarkedTrails.mtb
# WaymarkedTrails.riding
# WaymarkedTrails.skating
# WaymarkedTrails.slopes
# nlmaps.grijs
# nlmaps.luchtfoto
# nlmaps.pastel
# nlmaps.standaard
# nlmaps.water

# %%
Map.add_basemap('OpenTopoMap')
